# %% [markdown]
# **Introduction**
# The ability to extract meaningful insights from vast amounts of data is a highly sought-after skill in today's data-driven world. As I set out to find valuable insights, I turned to a powerful tool: data visualization.
#
# "Unleashing the Power of Data Visualization for Uncovering New Insights" refers to the investigation and application of data visualization techniques in order to extract valuable information and gain a deeper understanding of complex datasets. It emphasizes the power of visual representations to reveal patterns, trends, and correlations that would be difficult to detect using traditional data analysis methods.
# We can transform raw data into visually appealing and intuitive visualizations such as charts, graphs, and interactive dashboards by using data visualization. These visual representations help us better understand and interpret data, allowing us to discover new insights that would otherwise go unnoticed.
#
# Data visualization acts as the bridge between data and human perception, taking advantage of our innate ability to process visual information quickly and efficiently. It assists us in identifying relationships, outliers, and emerging trends within datasets, allowing us to make informed decisions and take strategic actions based on evidence-backed insights. In this blog post, we will look at how data visualization can help you discover new perspectives, improve data analysis, make better decisions, and plot some visualization examples.
#
# Important of visualization
# The Art of Visual Storytelling: Data visualization is a powerful storytelling medium. It enables us to express complex ideas and patterns with ease by transforming raw data into visually compelling representations. The art of visual storytelling refers to the practice of using visual elements, such as images, graphics, and animations, to convey narratives, messages, and emotions. Visual storytelling allows data analysts, researchers, and presenters to communicate complex information in a more accessible and engaging way.
#
# Uncovering Hidden Patterns and Trends: Visualizing data brings hidden patterns and trends to light. The process of revealing insights and relationships within data that are not immediately apparent or easily discernible is referred to as uncovering hidden patterns and trends. It entails employing analytical techniques and data visualization to identify meaningful patterns, trends, correlations, and anomalies in a dataset.
# Data visualization is critical to revealing these hidden patterns and trends. Patterns that may not be visible in raw data become more visible when the data is visually represented in charts, graphs, maps, or other visual formats. Analysts can use visualizations to observe relationships, identify clusters, track changes over time, and identify outliers or anomalies.
#
# Improving Data Analysis: Traditional data analysis methods can be overwhelming at times, leaving us unable to see the big picture. By utilizing the power of data visualization, we can achieve a new level of understanding and simplicity.

# %% [markdown]
# For specific data visualization needs, there are numerous other types of charts and variations available. Here are a few examples, each with a brief explanation and code; later on, two out of the given examples will be selected and explained in depth.
# ##
# **A lollipop chart** is a type of data visualization that combines elements of a scatter plot and a bar chart. It is also known as a dot plot or a barbell chart. It is used to show and compare values for various categories or groups. In a lollipop chart, data points are represented by individual dots or circles, similar to a scatter plot.Some important parts of the lollipop chart are:
# ##
# Lollipop charts are useful for comparing values across different categories or groups and highlighting differences or patterns.
# ##
# They are particularly effective when you have numerical or quantitative data and want to display the magnitude or value associated with each category.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
ADS_ladies = ['Farida', 'Fatima', 'Maryam', 'Deborah', 'Rahma', 'zarau']
puntuality = [10, 20, 15.7, 9, 33.3, 44.9]

# Plotting
plt.stem(ADS_ladies, puntuality, basefmt=' ')
plt.xticks(ADS_ladies)
plt.ylabel('Values')
plt.title('Puntuality level of ArewaDS ladies')

# Display
plt.show()

# %% [markdown]
# **A pie chart:** displays data as slices of a circular "pie," with each slice representing a category or proportion of the total. It is appropriate for displaying relative proportions or percentages. Some important parts of pie chart are:
# ##
# It is best used to show the relative proportions or percentages of different categories or parts of a whole.
# #
# Pie charts are effective when you have categorical data and want to emphasize the composition or distribution of the data.

# %%
import matplotlib.pyplot as plt

# Data
ADS_ladies = ['Farida', 'Fatima', 'Maryam', 'Deborah', 'Rahma', 'zarau']
sizes = [25, 35, 40, 38, 50, 63]

# Plotting
plt.pie(sizes, labels= ADS_ladies, autopct='%1.1f%%')

# Title
plt.title('Arewa data science ladies')

# Display
plt.show()

# %% [markdown]
# **A scatter plot:** is a graph that displays individual data points as dots, with each point representing two variables. It aids in the visualization of the relationship or correlation between variables.

# %%
#displayoyn the scatter plot chart
ADS_ladies = ['Farida', 'Fatima', 'Maryam', 'Deborah', 'Rahma', 'zarau']
puntuality = [10, 20, 15.7, 9, 33.3, 44.9]
plt.scatter(ADS_ladies, puntuality)

plt.xticks(ADS_ladies)
plt.ylabel(puntuality)
plt.title("scatter plot displying the puntuality of ladies in ADS")

plt.show()

# %% [markdown]
# **A Heatmap:** is a graphical representation of data that uses colors to indicate the intensity or density of values in a matrix or grid format. It is frequently used in large datasets to visualize correlations, patterns, or clustering. For the heatmap, when trying to plot it, we need to import the two most important libraries for visualization, which are Seaborn and Matplotlib, as shown in the example below:

# %%
#heatmap chart
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
#ADS_ladies = ['Farida', 'Fatima', 'Maryam', 'Deborah', 'Rahma', 'zarau']
#Participating_in_office_hours = ['saturday','sunday', 'tuesdays', 'wedsday','friday', 'monday']
ADS_ladies = np.random.rand(5,5)
#PLOTTING
sns.heatmap(ADS_ladies, #Participating_in_office_hours
            annot= True, cmap='YlOrRd')
plt.title('relationship within the ladies and atteding office hours')

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Define the data
ADS_ladies = ['Farida', 'Fatima', 'Maryam', 'Deborah', 'Rahma', 'Zarau']
Participating_in_office_hours = ['Saturday', 'Sunday', 'Tuesday', 'Wednesday', 'Friday', 'Monday']

# Create a list to represent the heatmap data that 6x6 matrics of random numbers 
data = [[1, 0, 1, 0, 4, 1],
        [1, 0, 3, 0, 1, 0],
        [0, 1, 0, 1, 0, 0],
        [0, 1, 0, 2, 0, 1],
        [1, 0, 1, 0, 0, 3],
        [0, 2, 1, 1, 0, 0]]

# Create a heatmap using seaborn
sns.heatmap(data, cmap='YlGnBu', annot=True, fmt='d', xticklabels=Participating_in_office_hours, yticklabels=ADS_ladies)

# Add labels and title
plt.xlabel('Participating in Office Hours')
plt.ylabel('ADS Ladies')
plt.title('ADS Ladies Participation in Office Hours')

# Display the heatmap
plt.show()

# %% [markdown]
# The sns.heatmap() function is used to create the heatmap. The data parameter is passed to specify the data for the heatmap. The cmap parameter sets the color map for the heatmap (in this case, 'YlGnBu' is used). The annot parameter is set to True to display the numeric values in each cell of the heatmap. The fmt parameter specifies the format of the numbers displayed in the cells (in this case, 'd' represents integers). Want to learn more about heatmaps? No problem, just check the heatmap.

# %% [markdown]
# NOTE: When you're dealing with a large dataset in which you have read its file, whether in csv or any other format, all you need to do is pass or call the column names you want to show the relationship, so the matrix set of data is no longer needed, as shown in the example above.

# %% [markdown]
# **A bar chart:** represents data values using rectangular bars. It is useful for comparing discrete categories or demonstrating changes over time.

# %%
#displaying  the bar plot chart
ADS_ladies = ['Farida', 'Fatima', 'Maryam', 'Deborah', 'Rahma', 'zarau']
puntuality = [57, 60, 59, 45, 33.3, 44.9]

#plotting the bar chart
plt.bar(ADS_ladies, puntuality)
#plt.xticks('ADS_ladies')
plt.ylabel('puntuality')
plt.xlabel('ADS_ladies')

#title
plt.title('ADS_ladies Puntuallity\n')
plt.show()

# %% [markdown]
# In a situation where the labels or category names are long and may not fit well on the y-axis, we can use Barh or rotate the labels to some degree (e.g., 45, 60, or 90). They are also useful when there are many categories to display. as shown in the example below:

# %%
ADS_ladies = ['Farida', 'Fatima', 'Maryam', 'Deborah', 'Rahma', 'Zarau']
punctuality = [57, 60, 59, 45, 33.3, 44.9]

# Create a bar chart
plt.barh(ADS_ladies, punctuality)

# Add labels and title
plt.xlabel('ADS Ladies')
plt.ylabel('Punctuality')
plt.title('ADS Ladies Punctuality')

# Display the bar chart
plt.show()

# %% [markdown]
# for more on the bar chart click on the link or link
# #
# **Line Chart:** A line chart displays data points connected by lines. It is useful for showing trends and changes in data over time.

# %%
ADS_ladies = ['Farida', 'Fatima', 'Maryam', 'Deborah', 'Rahma', 'Zarau']
punctuality = [57, 60, 59, 45, 33.3, 44.9]

plt.plot(ADS_ladies, puntuality, linestyle = '-', marker = '*', color ='r')
plt.xlabel('ADS_ladies')
plt.ylabel('punctuality')
plt.title('puntuality')

plt.show()

# %% [markdown]
# The marker parameter is set to '*' to display a star marker at each data point, the linestyle parameter is set to '-' to connect the data points with lines, and the color parameter is set to 'r' for blue red.

# %% [markdown]
# **Box Plot:** A box plot (or box-and-whisker plot) depicts a dataset's distribution using quartiles, displaying the minimum, maximum, median, and outliers.

# %%
#dispalying the box plot
ADS_ladies = ['Farida', 'Fatima', 'Maryam', 'Deborah', 'Rahma', 'Zarau']
punctuality = [55.7, 60.9, 59, 45, 33.3, 44.9]

#let create a dictionary to hold the data 
data ={'ADS_ladies': ADS_ladies, 'punctuality': punctuality}

df = pd.DataFrame(data)

sns.boxplot( x='ADS_ladies', y= 'punctuality', data= df)

plt.xlabel('ADS_ladies')
plt.ylabel('punctuality')
plt.title('puntuality of ADSladies')


plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Define the data
ADS_ladies = ['Farida', 'Fatima', 'Maryam', 'Deborah', 'Rahma', 'Zarau']
punctuality = [57, 60, 59, 45, 33.3, 44.9]

# Create a dictionary to hold the data
data = {'ADS Ladies': ADS_ladies, 'Punctuality': punctuality}

# Create a DataFrame from the data
df = pd.DataFrame(data)

# Create a box plot using seaborn
sns.boxplot(x='ADS Ladies', y='Punctuality', data=df)

# Add labels and title
plt.xlabel('ADS Ladies')
plt.ylabel('Punctuality')
plt.title('Punctuality of ADS Ladies')

# Rotate x-axis labels if needed
plt.xticks(rotation=45)

# Display the box plot
plt.show()

# %% [markdown]
# **Histogram:** A histogram displays the distribution of a continuous variable by dividing it into bins and showing the frequency or count of values within each bin.

# %%
import matplotlib.pyplot as plt

# Define the data
ADS_ladies = ['Farida', 'Fatima', 'Maryam', 'Deborah', 'Rahma', 'Zarau']
punctuality = [55.7, 60.9, 59, 45, 33.3, 44.9]

# Create a histogram using matplotlib
plt.hist(punctuality, bins=10, edgecolor='red')

# Add labels and title
plt.xlabel('Punctuality')
plt.ylabel('Frequency')
plt.title('Punctuality Distribution of ADS Ladies')

# Add x-axis labels
plt.xticks(range(30, 70, 5))

# Display the histogram
plt.show()

# %% [markdown]
# The plt.hist() function from the matplotlib library is used to create the histogram. The punctuality list is passed as the data for the histogram, and the bins parameter is set to 10 to specify the number of bins or intervals for the histogram. The edgecolor parameter sets the color of the edges of the bars.
# #
# **Area chart:** An area chart is similar to a line chart, but the area between the line and the x-axis is colored. It can be used to display cumulative data or to compare multiple data series.

# %%
import matplotlib.pyplot as plt

# Define the data
ADS_ladies = ['Farida', 'Fatima', 'Maryam', 'Deborah', 'Rahma', 'Zarau']
punctuality = [45, 33.3, 57, 60, 59,  44.9]

# Create the area chart
plt.fill_between(range(len(ADS_ladies)), punctuality, color='yellow', alpha=0.4)

# Add labels and title
plt.xlabel('ADS Ladies')
plt.ylabel('Punctuality (%)')
plt.title('Punctuality of ADS Ladies')

# Customize the x-axis labels
plt.xticks(range(len(ADS_ladies)), ADS_ladies)

# Display the area chart
plt.show()

# %% [markdown]
# The fill_between() function from the plt module is used to create the area chart by filling the area between the data points and the x-axis.
#
# The color parameter sets the color of the area, and the alpha parameter controls the transparency of the area. In this example, the area is filled with a yellow color and has an alpha value of 0.4. Click this link for more information on the area chart.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the data
ADS_ladies = ['Farida', 'Fatima', 'Maryam', 'Deborah', 'Rahma', 'Zarau']
punctuality = [57, 60, 59, 45, 33.3, 44.9]

# Create a figure and axes
fig, ax = plt.subplots()

# Set the y-axis range
ax.set_ylim([0, 100])

# Create horizontal bars for punctuality
y_pos = np.arange(len(ADS_ladies))
ax.barh(y_pos, punctuality, align='center', color='blue')

# Set y-axis ticks and labels
ax.set_yticks(y_pos)
ax.set_yticklabels(ADS_ladies)

# Set x-axis label
ax.set_xlabel('Punctuality')

# Add data labels to the bars
for i, v in enumerate(punctuality):
    ax.text(v + 1, i, str(v), color='black')

# Set title
ax.set_title('ADS Ladies Punctuality')

# Display the chart
plt.show()

# %% [markdown]
# **Conclusion**
#
# In conclusion, "Unleashing the Power of Data Visualization for Uncovering New Insights" emphasizes the importance of using data visualization techniques to uncover hidden potential within datasets, extract valuable insights, and drive impactful decision-making processes. Selecting the right chart in data analysis is crucial for effective communication, data visualization, simplified interpretation, storytelling, data exploration, and audience-focused analysis. It enhances the clarity, impact, and understanding of the data, enabling analysts to derive meaningful insights and support decision-making processes. Thank you for reading, and I wish you happy learning.
